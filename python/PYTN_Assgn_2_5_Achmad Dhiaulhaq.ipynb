# %% [markdown]
# Achmad Dhiaulhaq PYTN-KS018-019

# %% [markdown]
# import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import scipy.stats
import statistics
import math
import scipy.stats as st

# %% [markdown]
# import dataset

# %%
data_nyc = pd.read_csv(r"C:\Users\Adi\Downloads\archive (5)\nyc-rolling-sales.csv")

# %%
data_nyc.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %%
data_nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
# ...

# %% [markdown]
# ### Cleaning data

# %%
# Membersihkan data menggunakan fungsi replace dengan mengganti semua data eror menjadi 0
data_nyc.replace(' -  ', 0,  inplace=True)
data_nyc.replace(' ', 0,  inplace=True)
data_nyc.replace(np.nan, 0,  inplace=True)
data_nyc
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# ...           ...      ...            ...
# 84543        8409        5        WOODROW
# 84544        8410        5        WOODROW
# 84545        8411        5        WOODROW
# 84546        8412        5        WOODROW
# 84547        8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...

# %%
# Mengecek data duplikat
data_nyc.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Mengubah data object menjadi data interger

# %%
# Mengecek tipe data object
data_nyc.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   NEIGHBORHOOD                    84548 non-null  object
#  1   BUILDING CLASS CATEGORY         84548 non-null  object
#  2   TAX CLASS AT PRESENT            84548 non-null  object
#  3   BUILDING CLASS AT PRESENT       84548 non-null  object
#  4   ADDRESS                         84548 non-null  object
#  5   APARTMENT NUMBER                84548 non-null  object
#  6   LAND SQUARE FEET                84548 non-null  object
#  7   GROSS SQUARE FEET               84548 non-null  object
#  8   BUILDING CLASS AT TIME OF SALE  84548 non-null  object
#  9   SALE PRICE                      84548 non-null  object
#  10  SALE DATE                       84548 non-null  object
# dtypes: object(11)
# memory usage: 7.1+ MB

# %%
# mengubah data object menjadi interger
data_nyc['LAND SQUARE FEET'] = data_nyc['LAND SQUARE FEET'].astype(int)
data_nyc['GROSS SQUARE FEET'] = data_nyc['GROSS SQUARE FEET'].astype(int)

# %% [markdown]
# ### Membuat data hanya tipe data interger

# %%
### menghapus beberapa kolom dengan tipe data object untuk memudahkan perhitungan 
data_int = pd.read_csv(r"C:\Users\Adi\Downloads\archive (5)\nyc-rolling-sales.csv")
del data_int['NEIGHBORHOOD']
del data_int['BUILDING CLASS CATEGORY']
del data_int['APARTMENT NUMBER']
del data_int['BUILDING CLASS AT TIME OF SALE']
del data_int['SALE DATE']
del data_int['SALE PRICE']
del data_int['TAX CLASS AT PRESENT']
del data_int['BUILDING CLASS AT PRESENT']
del data_int['ADDRESS']
del data_int['EASE-MENT']

# %%
# Cleaning data_int
data_int.replace(' -  ', 0,  inplace=True)
data_int.replace(' ', 0,  inplace=True)
data_int.replace(np.nan, 0,  inplace=True)

# %%
# Mengubah tipe data object menjadi interger
data_int['LAND SQUARE FEET'] = data_int['LAND SQUARE FEET'].astype(int)
data_int['GROSS SQUARE FEET'] = data_int['GROSS SQUARE FEET'].astype(int)

# %%
# Mengecek tipe data object yang tersedia
data_int.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Empty DataFrame

# %% [markdown]
# ### Membuat kolom Sale perbulan dan pertahun

# %%
data_nyc['SALE DATE'] = pd.to_datetime(data_nyc['SALE DATE'])
data_nyc['SALE_MONTH']= data_nyc['SALE DATE'].dt.month
data_nyc['SALE_YEAR'] = data_nyc['SALE DATE'].dt.year
data_nyc
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# ...           ...      ...            ...
# 84543        8409        5        WOODROW
# 84544        8410        5        WOODROW
# 84545        8411        5        WOODROW
# 84546        8412        5        WOODROW
# 84547        8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...

# %% [markdown]
# ### Mean, Standar Deviasi

# %%
# Mencari mean dan standar deviasi menggunakan fungi describe
data_nyc.describe()
# Out:
#          Unnamed: 0       BOROUGH         BLOCK           LOT  EASE-MENT  \
# count  84548.000000  84548.000000  84548.000000  84548.000000    84548.0
# mean   10344.359878      2.998758   4237.218976    376.224015        0.0
# std     7151.779436      1.289790   3568.263407    658.136814        0.0
# min        4.000000      1.000000      1.000000      1.000000        0.0
# 25%     4231.000000      2.000000   1322.750000     22.000000        0.0
# 50%     8942.000000      3.000000   3311.000000     50.000000        0.0
# 75%    15987.250000      4.000000   6281.000000   1001.000000        0.0
# max    26739.000000      5.000000  16322.000000   9106.000000        0.0
#
#            ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  \
# count  84548.000000       84548.000000      84548.000000  84548.000000
# mean   10731.991614           2.025264          0.193559      2.249184
# std     1290.879147          16.721037          8.713183     18.972584
# ...

# %% [markdown]
# ### Median

# %%
data_nyc.median()
# Out:
# Unnamed: 0                     8942.0
# BOROUGH                           3.0
# BLOCK                          3311.0
# LOT                              50.0
# EASE-MENT                         0.0
# ZIP CODE                      11209.0
# RESIDENTIAL UNITS                 1.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       1.0
# LAND SQUARE FEET               1770.0
# GROSS SQUARE FEET              1076.0
# YEAR BUILT                     1940.0
# TAX CLASS AT TIME OF SALE         2.0
# SALE PRICE                   415000.0
# SALE_MONTH                        6.0
# SALE_YEAR                      2017.0
# dtype: float64

# %% [markdown]
# ### Modus

# %%
# Membuat data modus
modus = data_nyc.mode()

# Mencetak data modus hanya satu kolom
modus.head(1)
# Out:
#    Unnamed: 0  BOROUGH    NEIGHBORHOOD  \
# 0           4      4.0  FLUSHING-NORTH
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT   BLOCK  \
# 0  01 ONE FAMILY DWELLINGS                                        1  5066.0
#
#    LOT  EASE-MENT BUILDING CLASS AT PRESENT             ADDRESS  ...  \
# 0  1.0        0.0                        D4  131-05 40TH   ROAD  ...
#
#   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0         1.0               0.0                0.0         0.0
#
#    TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                        1.0                              R4           0
#
#    SALE DATE  SALE_MONTH SALE_YEAR
# 0 2017-06-29         6.0    2017.0
#
# [1 rows x 24 columns]

# %% [markdown]
# ### Range

# %%
# Membuat nilai max dan min
max = data_int.max()
min = data_int.min()

# Membuat range
range = max-min
range
# Out:
# Unnamed: 0                     26735
# BOROUGH                            4
# BLOCK                          16321
# LOT                             9105
# ZIP CODE                       11694
# RESIDENTIAL UNITS               1844
# COMMERCIAL UNITS                2261
# TOTAL UNITS                     2261
# LAND SQUARE FEET             4252327
# GROSS SQUARE FEET            3750565
# YEAR BUILT                      2017
# TAX CLASS AT TIME OF SALE          3
# dtype: int64

# %% [markdown]
# ### Variance

# %%
# Mencari variance
data_nyc.var()
# Out:
# Unnamed: 0                   5.114795e+07
# BOROUGH                      1.663558e+00
# BLOCK                        1.273250e+07
# LOT                          4.331441e+05
# EASE-MENT                    0.000000e+00
# ZIP CODE                     1.666369e+06
# RESIDENTIAL UNITS            2.795931e+02
# COMMERCIAL UNITS             7.591956e+01
# TOTAL UNITS                  3.599590e+02
# LAND SQUARE FEET             1.218673e+09
# GROSS SQUARE FEET            8.300622e+08
# YEAR BUILT                   2.887396e+05
# TAX CLASS AT TIME OF SALE    6.713200e-01
# SALE_MONTH                   1.202161e+01
# SALE_YEAR                    2.271508e-01
# dtype: float64

# %% [markdown]
# ### Probability distribution

# %%
# Membuat fungsi value
value = data_nyc.value_counts()

# untuk mencari kemungkinan value dibagi jumlah data
probability = value/len(data_nyc)
print("distribusi probababilitas:")
probability
# Out:
# distribusi probababilitas:
# Unnamed: 0  BOROUGH  NEIGHBORHOOD             BUILDING CLASS CATEGORY                      TAX CLASS AT PRESENT  BLOCK  LOT   EASE-MENT  BUILDING CLASS AT PRESENT  ADDRESS                 APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  SALE PRICE  SALE DATE   SALE_MONTH  SALE_YEAR
# 4           1        ALPHABET CITY            07 RENTALS - WALKUP APARTMENTS               2A                    392    6     0          C2                         153 AVENUE B            0                 10009     5                  0                 5            1633              6440               1900        2                          C2                              6625000     2017-07-19  7           2017         0.000012
# ...

# %% [markdown]
# ### confidence interval

# %%
st.norm.interval(alpha=0.90, 
                 loc=np.mean(data_int), 
                 scale=st.sem(data_int))
# Out:
# (array([1.03039032e+04, 2.99146194e+00, 4.21703380e+03, 3.72501026e+02,
#         1.07246893e+04, 1.93067516e+00, 1.44269412e-01, 2.14185860e+00,
#         2.52031442e+03, 2.56146657e+03, 1.78628329e+03, 1.65284961e+00]),
#  array([1.03848165e+04, 3.00605427e+00, 4.25740415e+03, 3.79947004e+02,
#         1.07392939e+04, 2.11985236e+00, 2.42847965e-01, 2.35650919e+00,
#         2.91527083e+03, 2.88742402e+03, 1.79236266e+03, 1.66211941e+00]))

# %% [markdown]
# ### Hipotesis

# %% [markdown]
# Properti dibeli terbanyak pada bulan juni tahun 2017 dan daerah nomor 4. Dapat disimpulkan bahwa daerah nomor 4 memiliki perekonomian yang baik pada pertengahan tahun 2017
