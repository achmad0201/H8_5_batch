# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Soal no 1

# %%
df = pd.read_excel(r"C:\Users\Adi\Downloads\Dataset grup A.xlsx") ### file tergantung dari user

# %%
df
# Out:
#    No. Peserta                                   Nama  \
# 0       DS5A01                  Najla Atikah Dwirahma
# 1       DS5A02                            Rahmi Najla
# 2       DS5A03                           Wafiq Azizah
# 3       DS5A04                     Alamsyah Dwi Putra
# 4       DS5A05                          Icha Patricia
# 5       DS5A06                             Nurhasanah
# 6       DS5A07                    Ismatu Laila Syifa'
# 7       DS5A08  Shalli Dyangrosa Permatanurani Balqis
# 8       DS5A09                             Dewi Ayati
# 9       DS5A10                    Nuril Alim Abidin
# 10      DS5A11                     Aisyah Hayya Imani
# 11      DS5A12                          Nanang Arifin
# 12      DS5A13   Abigail Dorothy Hertaruli Oppusunggu
# 13      DS5A14                     Sinta Dwi Rosalia
# 14      DS5A15                           Asima Manalu
# 15      DS5A16                         Oxana Fedorova
# ...

# %% [markdown]
# ### Soal no 2

# %% [markdown]
# ### Soal no 3

# %%
for BMI in df:
    BMI = df['Berat Badan (kg)'] / (df['Tinggi Badan (cm)'] ** 2)
print(BMI)
# Out:
# 0     0.001701
# 1     0.002178
# 2     0.001687
# 3     0.002353
# 4     0.002231
# 5     0.002344
# 6     0.002193
# 7     0.002045
# 8     0.001665
# 9     0.002473
# 10    0.001644
# 11    0.002045
# 12    0.002126
# 13    0.002383
# 14    0.002057
# 15    0.001911
# 16    0.001831
# 17    0.002278
# 18    0.001953
# 19    0.001579
# 20    0.002204
# 21    0.001859
# 22    0.001996
# 23    0.002203
# dtype: float64

# %% [markdown]
# ### Soal no 4

# %%
df['BMI'] = pd.DataFrame(BMI)
df.insert(5, 'BMI', BMI)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 2
#       1 df['BMI'] = pd.DataFrame(BMI)
# ----> 2 df.insert(5, 'BMI', BMI)
#       3 df
#
# File c:\Users\Adi\anaconda3\Lib\site-packages\pandas\core\frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert BMI, already exists

# %% [markdown]
# ### Soal no 5

# %%
print(df.drop('5', axis=1))
df
# Out:
#    No. Peserta                                   Nama       BMI  \
# 0       DS5A01                  Najla Atikah Dwirahma  0.001701
# 1       DS5A02                            Rahmi Najla  0.002178
# 2       DS5A03                           Wafiq Azizah  0.001687
# 3       DS5A04                     Alamsyah Dwi Putra  0.002353
# 4       DS5A05                          Icha Patricia  0.002231
# 5       DS5A06                             Nurhasanah  0.002344
# 6       DS5A07                    Ismatu Laila Syifa'  0.002193
# 7       DS5A08  Shalli Dyangrosa Permatanurani Balqis  0.002045
# 8       DS5A09                             Dewi Ayati  0.001665
# 9       DS5A10                    Nuril Alim Abidin    0.002473
# 10      DS5A11                     Aisyah Hayya Imani  0.001644
# 11      DS5A12                          Nanang Arifin  0.002045
# 12      DS5A13   Abigail Dorothy Hertaruli Oppusunggu  0.002126
# 13      DS5A14                     Sinta Dwi Rosalia   0.002383
# ...
