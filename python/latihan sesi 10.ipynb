# %% [markdown]
# ### Achmad Dhiaulhaq PYTN-KS018-019

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\Users\Adi\Documents\codingan\data\melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 3  4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 4  4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN       Yarra   -37.7996    144.9984
# ...

# %% [markdown]
# ### 1

# %%
kolom = ['Rooms', 'Distance', 'Landsize', 'Price']
data = df[kolom]
data_kolom = data.describe()
data_kolom
# Out:
#               Rooms      Distance       Landsize         Price
# count  13580.000000  13580.000000   13580.000000  1.358000e+04
# mean       2.937997     10.137776     558.416127  1.075684e+06
# std        0.955748      5.868725    3990.669241  6.393107e+05
# min        1.000000      0.000000       0.000000  8.500000e+04
# 25%        2.000000      6.100000     177.000000  6.500000e+05
# 50%        3.000000      9.200000     440.000000  9.030000e+05
# 75%        3.000000     13.000000     651.000000  1.330000e+06
# max       10.000000     48.100000  433014.000000  9.000000e+06

# %% [markdown]
# ### 2

# %% [markdown]
# a

# %%
df["Rooms"].max()
# Out:
# 10

# %% [markdown]
# b

# %%
df["Distance"].mean()
# Out:
# 10.13777614138439

# %% [markdown]
# ### 3

# %% [markdown]
# ### a

# %%
Q1 = df['Price'].quantile(0.25)
Q2 = df['Price'].quantile(0.50)
Q3 = df['Price'].quantile(0.75)
print("Q1:", Q1)
print("Q2:", Q2)
print("Q3:", Q3)
# Out:
# Q1: 650000.0
# Q2: 903000.0
# Q3: 1330000.0

# %% [markdown]
# ### b

# %%
IQR = Q3-Q1
terendah = Q1 - 1.5 * IQR
tertinggi = Q3 + 1.5 * IQR

outliers = df[(df['Price'] < terendah) | (df['Price'] > tertinggi)]

outliers
# Out:
#                Suburb               Address  Rooms Type      Price Method  \
# 80        Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 92        Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 97        Albert Park         70 Barrett St      3    h  2575000.0      S
# 102       Albert Park            97 Page St      3    h  3010000.0      S
# 103       Albert Park         55 Withers St      4    h  2800000.0     VB
# ...               ...                   ...    ...  ...        ...    ...
# 13521  Port Melbourne          44 Garton St      4    t  2455000.0     SP
# 13523         Prahran        69 Greville St      4    h  2668000.0      S
# 13553    Surrey Hills          20 Albert Cr      4    h  2720000.0      S
# 13555    Surrey Hills              3 Oak St      4    h  3100000.0     VB
# 13578    Williamstown          96 Verdon St      4    h  2500000.0     PI
#
#         SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %% [markdown]
# ### 4

# %% [markdown]
# a

# %%
import scipy.stats as stats
data = df["Price"]
shapiro_test_stat, shapiro_p_value = stats.shapiro(data)
shapiro_test_stat
shapiro_p_value
# Out:
# c:\Users\Adi\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# 0.0

# %% [markdown]
# b

# %%
dagostino_test_stat, dagostino_p_value = stats.normaltest(data)
dagostino_test_stat
dagostino_p_value
# Out:
# 0.0

# %% [markdown]
# ### 9

# %%
from scipy.stats import chi2_continqency
data = df['Type'], df["Method"]
stat, p, dof, expected = chi2_continqency(data)

alpha = 0.05
print("p value is", str(p))
if p <= alpha:
    print("depent (reject H0)")
else:
    print("indenpendent (H0 holds true)")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\Adi\Documents\codingan\python\latihan sesi 10.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adi/Documents/codingan/python/latihan%20sesi%2010.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> from scipy.stats import chi2_continqency
#       <a href='vscode-notebook-cell:/c%3A/Users/Adi/Documents/codingan/python/latihan%20sesi%2010.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> data = df['Type'], df["Method"]
#       <a href='vscode-notebook-cell:/c%3A/Users/Adi/Documents/codingan/python/latihan%20sesi%2010.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> stat, p, dof, expected = chi2_continqency(data)
#
# ImportError: cannot import name 'chi2_continqency' from 'scipy.stats' (c:\Users\Adi\anaconda3\Lib\site-packages\scipy\stats\__init__.py)

# %% [markdown]
# ### 10

# %%
from scipy.stats import f_oneway


# Pisahkan data menjadi kelompok-kelompok berdasarkan Regionname
groups = [group['Price'] for name, group in df.groupby('Regionname')]

# Lakukan uji ANOVA
stat, p = f_oneway(*groups)

# Menampilkan hasil uji
print("Statistik ANOVA:", stat)
print("P-Value:", p)

alpha = 0.05

# Ambil keputusan
if p < alpha:
    print("Menolak hipotesis nol (Ho): Setidaknya ada satu pasang Regionname yang rata-rata harga rumahnya tidak sama.")
else:
    print("Tidak cukup bukti untuk menolak hipotesis nol (Ho): Rata-rata harga rumah antar Regionname sama.")
# Out:
# Statistik ANOVA: 284.40018651008097
# P-Value: 0.0
# Menolak hipotesis nol (Ho): Setidaknya ada satu pasang Regionname yang rata-rata harga rumahnya tidak sama.
